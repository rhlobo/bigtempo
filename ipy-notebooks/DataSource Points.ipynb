# %%
from instances import data_engine

# %%
from datasources import *

# %%
from datasources.point import point

# %%
@data_engine.for_synched(data_engine.select('NORMALIZED'), data_engine.select('MACD'))
def _create_point(base_reference, macd_reference):

    @point('MACD_HISTOGRAM_CROSS_UP_POINT:%s' % macd_reference, base_reference, dependencies=[macd_reference])
    class Point(object):
    
        def evaluate(self, context, registor):
            if context[macd_reference]['macdhist'].ix[0] < 0 and context[macd_reference]['macdhist'].ix[1] > 0:
                registor.add(context['base']['close'].ix[1])

# %%
sorted(data_engine.select('POINT'))
# Out:
# ['MACD_HISTOGRAM_CROSS_UP_POINT:MACD(12,26,3):CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA',
#  'MACD_HISTOGRAM_CROSS_UP_POINT:MACD(12,26,3):CLOSE:MONTHLY:NORMALIZED:RAW_YAHOO_BR',
#  'MACD_HISTOGRAM_CROSS_UP_POINT:MACD(12,26,3):CLOSE:NORMALIZED:RAW_BOVESPA',
#  'MACD_HISTOGRAM_CROSS_UP_POINT:MACD(12,26,3):CLOSE:NORMALIZED:RAW_YAHOO_BR',
#  'MACD_HISTOGRAM_CROSS_UP_POINT:MACD(12,26,3):CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA',
#  'MACD_HISTOGRAM_CROSS_UP_POINT:MACD(12,26,3):CLOSE:WEEKLY:NORMALIZED:RAW_YAHOO_BR',
#  'MACD_HISTOGRAM_CROSS_UP_POINT:MACD(12,26,9):CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA',
#  'MACD_HISTOGRAM_CROSS_UP_POINT:MACD(12,26,9):CLOSE:MONTHLY:NORMALIZED:RAW_YAHOO_BR',
#  'MACD_HISTOGRAM_CROSS_UP_POINT:MACD(12,26,9):CLOSE:NORMALIZED:RAW_BOVESPA',
#  'MACD_HISTOGRAM_CROSS_UP_POINT:MACD(12,26,9):CLOSE:NORMALIZED:RAW_YAHOO_BR',
#  'MACD_HISTOGRAM_CROSS_UP_POINT:MACD(12,26,9):CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA',
#  'MACD_HISTOGRAM_CROSS_UP_POINT:MACD(12,26,9):CLOSE:WEEKLY:NORMALIZED:RAW_YAHOO_BR',
#  'MACD_HISTOGRAM_CROSS_UP_POINT:MACD(5,35,5):CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA',
#  'MACD_HISTOGRAM_CROSS_UP_POINT:MACD(5,35,5):CLOSE:MONTHLY:NORMALIZED:RAW_YAHOO_BR',
#  'MACD_HISTOGRAM_CROSS_UP_POINT:MACD(5,35,5):CLOSE:NORMALIZED:RAW_BOVESPA',
#  'MACD_HISTOGRAM_CROSS_UP_POINT:MACD(5,35,5):CLOSE:NORMALIZED:RAW_YAHOO_BR',
#  'MACD_HISTOGRAM_CROSS_UP_POINT:MACD(5,35,5):CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA',
#  'MACD_HISTOGRAM_CROSS_UP_POINT:MACD(5,35,5):CLOSE:WEEKLY:NORMALIZED:RAW_YAHOO_BR']

# %%
from datetime import date as dt

# %%
data_engine.select('MACD_HISTOGRAM_CROSS_UP_POINT:MACD(12,26,3):CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA').get(0).process('PETR4')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 184 entries, 2003-01-31 00:00:00 to 2012-09-28 00:00:00
# Data columns:
# value    184  non-null values
# dtypes: float64(1)

# %%
data_engine.select('MACD_HISTOGRAM_CROSS_UP_POINT:MACD(12,26,3):CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA').get(0).process('PETR4')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 191 entries, 2000-08-18 00:00:00 to 2013-03-21 00:00:00
# Data columns:
# value    191  non-null values
# dtypes: float64(1)

# %%
data_engine.select('MACD_HISTOGRAM_CROSS_UP_POINT:MACD(12,26,3):CLOSE:NORMALIZED:RAW_BOVESPA').get(0).process('PETR4')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 180 entries, 2000-02-16 00:00:00 to 2013-03-06 00:00:00
# Data columns:
# value    180  non-null values
# dtypes: float64(1)

# %%
data_engine.select('MACD_HISTOGRAM_CROSS_UP_POINT:MACD(12,26,9):CLOSE:NORMALIZED:RAW_BOVESPA').get(0).process('PETR4', dt(2012, 1, 1), dt(2013, 3, 1))
# Out:
#             value
# 2012-01-05  22.31
# 2012-02-07  25.60
# 2012-03-02  25.30
# 2012-03-19  24.51
# 2012-04-26  21.24
# 2012-05-21  20.40
# 2012-07-03  18.99
# 2012-09-12  21.99
# 2012-12-03  19.00
# 2013-02-19  18.10

# %% [markdown]
# 2012-01-05	 22.31
# 2012-02-08	 25.43
# 2012-03-05	 24.59
# 2012-03-20	 24.27
# 2012-04-27	 20.93
# 2012-05-22	 19.71
# 2012-07-04	 18.95
# 2012-09-13	 22.90
# 2012-12-04	 18.82
# 2013-02-20	 17.6

# %%
w = data_engine.select('MACD(12,26,9):CLOSE:NORMALIZED:RAW_BOVESPA').get(0).process('PETR4', dt(2012, 1, 1), dt(2012, 3, 1))
w
# Out:
#                 macd  macdhist  macdsignal
# 2012-01-02 -0.006020 -0.094909    0.088889
# 2012-01-03  0.037074 -0.041452    0.078526
# 2012-01-04  0.083178  0.003721    0.079457
# 2012-01-05  0.097610  0.014523    0.083087
# 2012-01-06  0.109401  0.021051    0.088350
# 2012-01-09  0.141323  0.042379    0.098945
# 2012-01-10  0.186262  0.069854    0.116408
# 2012-01-11  0.220145  0.082990    0.137156
# 2012-01-12  0.257744  0.096471    0.161273
# 2012-01-13  0.281872  0.096479    0.185393
# 2012-01-16  0.345427  0.128027    0.217400
# 2012-01-17  0.403249  0.148680    0.254570
# 2012-01-18  0.489427  0.187886    0.301541
# 2012-01-19  0.538604  0.189650    0.348954
# 2012-01-20  0.571792  0.178271    0.393521
# 2012-01-23  0.663871  0.216280    0.447591
# 2012-01-24  0.749986  0.241916    0.508070
# 2012-01-26  0.770617  0.210037    0.560579
# 2012-01-27  0.758056  0.157981    0.600075
# 2012-01-30  0.731599  0.105219    0.626380
# 2012-01-31  0.702533  0.060923    0.641610
# 2012-02-01  0.702068  0.048366    0.653702
# 2012-02-02  0.660198  0.005197    0.655001
# 2012-02-03  0.626253 -0.022999    0.649252
# 2012-02-06  0.612464 -0.029430    0.641894
# 2012-02-07  0.653712  0.009454    0.644258
# 2012-02-08  0.665018  0.016608    0.648410
# 2012-02-09  0.671881  0.018777    0.653104
# 2012-02-10  0.510058 -0.114437    0.624495
# 2012-02-13  0.446064 -0.142744    0.588809
# 2012-02-14  0.299105 -0.231762    0.530868
# 2012-02-15  0.171783 -0.287268    0.459051
# 2012-02-16  0.132294 -0.261405    0.393700
# 2012-02-17  0.113409 -0.224232    0.337642
# 2012-02-22  0.084557 -0.202468    0.287025
# 2012-02-23  0.063382 -0.178914    0.242296
# 2012-02-24  0.090741 -0.121244    0.211985
# 2012-02-27  0.100773 -0.088970    0.189743
# 2012-02-28  0.105888 -0.067084    0.172972
# 2012-02-29  0.107094 -0.052702    0.159796
# 2012-03-01  0.152288 -0.006007    0.158295
