# %%
import talib
import pandas
from datetime import date as dt

import providers.locator as locator
import providers.byproduct as byproduct

c_locator = locator.stock()

# %%
from instances import data_engine

# %%
from datasources import *

# %%
sorted(data_engine.select().all())
# Out:
# ['CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA',
#  'CLOSE:NORMALIZED:RAW_BOVESPA',
#  'CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA',
#  'MACD(12,26,3):CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA',
#  'MACD(12,26,3):CLOSE:NORMALIZED:RAW_BOVESPA',
#  'MACD(12,26,3):CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA',
#  'MACD(12,26,9):CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA',
#  'MACD(12,26,9):CLOSE:NORMALIZED:RAW_BOVESPA',
#  'MACD(12,26,9):CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA',
#  'MACD(5,35,5):CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA',
#  'MACD(5,35,5):CLOSE:NORMALIZED:RAW_BOVESPA',
#  'MACD(5,35,5):CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA',
#  'MONTHLY:NORMALIZED:RAW_BOVESPA',
#  'NORMALIZATION_FACTOR:SPLITS:PCT_CHANGE(1):RAW_BOVESPA',
#  'NORMALIZED:RAW_BOVESPA',
#  'PCT_CHANGE(1):RAW_BOVESPA',
#  'RAW_BOVESPA',
#  'SPLITS:PCT_CHANGE(1):RAW_BOVESPA',
#  'WEEKLY:NORMALIZED:RAW_BOVESPA']

# %%
sorted(data_engine.select().all().difference('{WEEKLY}').difference('{MONTHLY}').difference('MONTHLY'))
# Out:
# ['CLOSE:NORMALIZED:RAW_BOVESPA',
#  'MACD(12,26,3):CLOSE:NORMALIZED:RAW_BOVESPA',
#  'MACD(12,26,9):CLOSE:NORMALIZED:RAW_BOVESPA',
#  'MACD(5,35,5):CLOSE:NORMALIZED:RAW_BOVESPA',
#  'NORMALIZATION_FACTOR:SPLITS:PCT_CHANGE(1):RAW_BOVESPA',
#  'NORMALIZED:RAW_BOVESPA',
#  'PCT_CHANGE(1):RAW_BOVESPA',
#  'RAW_BOVESPA',
#  'SPLITS:PCT_CHANGE(1):RAW_BOVESPA',
#  'WEEKLY:NORMALIZED:RAW_BOVESPA']

# %%
data_engine.select().all()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-b094c7fe568f> in <module>()
# ----> 1 data_engine.select().all()
#
# /data/resemblanceProfiles/oncast-linux-PC/config/.virtualenvs/financial/local/lib/python2.7/site-packages/IPython/core/displayhook.pyc in __call__(self, result)
#     236             self.start_displayhook()
#     237             self.write_output_prompt()
# --> 238             format_dict = self.compute_format_data(result)
#     239             self.write_format_data(format_dict)
#     240             self.update_user_ns(result)
#
# /data/resemblanceProfiles/oncast-linux-PC/config/.virtualenvs/financial/local/lib/python2.7/site-packages/IPython/core/displayhook.pyc in compute_format_data(self, result)
#     148             MIME type representation of the object.
#     149         """
# --> 150         return self.shell.display_formatter.format(result)
#     151
#     152     def write_format_data(self, format_dict):
#
# /data/resemblanceProfiles/oncast-linux-PC/config/.virtualenvs/financial/local/lib/python2.7/site-packages/IPython/core/formatters.pyc in format(self, obj, include, exclude)
#     124                     continue
#     125             try:
# --> 126                 data = formatter(obj)
#     127             except:
#     128                 # FIXME: log the exception
#
# /data/resemblanceProfiles/oncast-linux-PC/config/.virtualenvs/financial/local/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     445                 type_pprinters=self.type_printers,
#     446                 deferred_pprinters=self.deferred_printers)
# --> 447             printer.pretty(obj)
#     448             printer.flush()
#     449             return stream.getvalue()
#
# /data/resemblanceProfiles/oncast-linux-PC/config/.virtualenvs/financial/local/lib/python2.7/site-packages/IPython/lib/pretty.pyc in pretty(self, obj)
#     358                             if callable(meth):
#     359                                 return meth(obj, self, cycle)
# --> 360             return _default_pprint(obj, self, cycle)
#     361         finally:
#     362             self.end_group()
#
# /data/resemblanceProfiles/oncast-linux-PC/config/.virtualenvs/financial/local/lib/python2.7/site-packages/IPython/lib/pretty.pyc in _default_pprint(obj, p, cycle)
#     478     if getattr(klass, '__repr__', None) not in _baseclass_reprs:
#     479         # A user-provided repr.
# --> 480         p.text(repr(obj))
#     481         return
#     482     p.begin_group(1, '<')
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
# ...
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in _to_string(self)
#     128
#     129     def _to_string(self):
# --> 130         return '<selection %s currently-with="%s">' % (self.__repr__(), json.dumps(list(self._selection), indent=4))
#
# /home/rhlobo/dev/workspace-py/stockExperiments/stockExperiments/bigtempo/tagselection.py in __repr__(self)
#      38
#      39     def __repr__(self):
# ---> 40         return self._to_string()
#      41
#      42     def __len__(self):
#
# RuntimeError: maximum recursion depth exceeded

# %%
def execute_all():
    for name, ds in data_engine.select().all().get().iteritems():
        print 'Executing %s' % name,
        result = ds.process(symbol='PETR4')
        print ': resulted data for %i periods.' % len(result)

# %%
# %timeit execute_all()
# Out:
# Executing MACD(12,26,9):CLOSE:NORMALIZED:RAW_BOVESPA
# : resulted data for 3245 periods.
# Executing CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA
# : resulted data for 159 periods.
# Executing MACD(5,35,5):CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA : resulted data for 121 periods.
# Executing CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA
# : resulted data for 691 periods.
# Executing MACD(12,26,3):CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA : resulted data for 664 periods.
# Executing NORMALIZED:RAW_BOVESPA
# : resulted data for 3278 periods.
# Executing WEEKLY:NORMALIZED:RAW_BOVESPA : resulted data for 691 periods.
# Executing SPLITS:PCT_CHANGE(1):RAW_BOVESPA : resulted data for 3 periods.
# Executing MACD(5,35,5):CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA
# : resulted data for 653 periods.
# Executing CLOSE:NORMALIZED:RAW_BOVESPA : resulted data for 3278 periods.
# Executing RAW_BOVESPA : resulted data for 3278 periods.
# Executing MONTHLY:NORMALIZED:RAW_BOVESPA
# : resulted data for 159 periods.
# Executing MACD(12,26,3):CLOSE:NORMALIZED:RAW_BOVESPA : resulted data for 3251 periods.
# Executing PCT_CHANGE(1):RAW_BOVESPA : resulted data for 3278 periods.
# Executing MACD(12,26,9):CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA
# : resulted data for 658 periods.
# Executing MACD(12,26,9):CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA : resulted data for 126 periods.
# Executing MACD(5,35,5):CLOSE:NORMALIZED:RAW_BOVESPA
# : resulted data for 3240 periods.
# Executing NORMALIZATION_FACTOR:SPLITS:PCT_CHANGE(1):RAW_BOVESPA : resulted data for 3513 periods.
# Executing MACD(12,26,3):CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA
# : resulted data for 132 periods.
# Executing MACD(12,26,9):CLOSE:NORMALIZED:RAW_BOVESPA : resulted data for 3245 periods.
# Executing CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA
# : resulted data for 159 periods.
# Executing MACD(5,35,5):CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA : resulted data for 121 periods.
# Executing CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA
# : resulted data for 691 periods.
# Executing MACD(12,26,3):CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA : resulted data for 664 periods.
# Executing NORMALIZED:RAW_BOVESPA : resulted data for 3278 periods.
# Executing WEEKLY:NORMALIZED:RAW_BOVESPA
# : resulted data for 691 periods.
# Executing SPLITS:PCT_CHANGE(1):RAW_BOVESPA : resulted data for 3 periods.
# Executing MACD(5,35,5):CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA : resulted data for 653 periods.
# Executing CLOSE:NORMALIZED:RAW_BOVESPA
# : resulted data for 3278 periods.
# Executing RAW_BOVESPA : resulted data for 3278 periods.
# Executing MONTHLY:NORMALIZED:RAW_BOVESPA : resulted data for 159 periods.
# Executing MACD(12,26,3):CLOSE:NORMALIZED:RAW_BOVESPA
# : resulted data for 3251 periods.
# Executing PCT_CHANGE(1):RAW_BOVESPA : resulted data for 3278 periods.
# Executing MACD(12,26,9):CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA : resulted data for 658 periods.
# Executing MACD(12,26,9):CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA
# : resulted data for 126 periods.
# Executing MACD(5,35,5):CLOSE:NORMALIZED:RAW_BOVESPA : resulted data for 3240 periods.
# Executing NORMALIZATION_FACTOR:SPLITS:PCT_CHANGE(1):RAW_BOVESPA : resulted data for 3513 periods.
# Executing MACD(12,26,3):CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA
# : resulted data for 132 periods.
# Executing MACD(12,26,9):CLOSE:NORMALIZED:RAW_BOVESPA : resulted data for 3245 periods.
# Executing CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA
# : resulted data for 159 periods.
# Executing MACD(5,35,5):CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA : resulted data for 121 periods.
# Executing CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA
# : resulted data for 691 periods.
# Executing MACD(12,26,3):CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA : resulted data for 664 periods.
# Executing NORMALIZED:RAW_BOVESPA : resulted data for 3278 periods.
# Executing WEEKLY:NORMALIZED:RAW_BOVESPA
# : resulted data for 691 periods.
# Executing SPLITS:PCT_CHANGE(1):RAW_BOVESPA : resulted data for 3 periods.
# Executing MACD(5,35,5):CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA : resulted data for 653 periods.
# Executing CLOSE:NORMALIZED:RAW_BOVESPA
# : resulted data for 3278 periods.
# Executing RAW_BOVESPA : resulted data for 3278 periods.
# Executing MONTHLY:NORMALIZED:RAW_BOVESPA : resulted data for 159 periods.
# Executing MACD(12,26,3):CLOSE:NORMALIZED:RAW_BOVESPA
# : resulted data for 3251 periods.
# Executing PCT_CHANGE(1):RAW_BOVESPA : resulted data for 3278 periods.
# Executing MACD(12,26,9):CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA : resulted data for 658 periods.
# Executing MACD(12,26,9):CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA
# : resulted data for 126 periods.
# Executing MACD(5,35,5):CLOSE:NORMALIZED:RAW_BOVESPA : resulted data for 3240 periods.
# Executing NORMALIZATION_FACTOR:SPLITS:PCT_CHANGE(1):RAW_BOVESPA : resulted data for 3513 periods.
# Executing MACD(12,26,3):CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA
# : resulted data for 132 periods.
# Executing MACD(12,26,9):CLOSE:NORMALIZED:RAW_BOVESPA : resulted data for 3245 periods.
# Executing CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA
# : resulted data for 159 periods.
# Executing MACD(5,35,5):CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA : resulted data for 121 periods.
# Executing CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA
# : resulted data for 691 periods.
# Executing MACD(12,26,3):CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA : resulted data for 664 periods.
# Executing NORMALIZED:RAW_BOVESPA : resulted data for 3278 periods.
# Executing WEEKLY:NORMALIZED:RAW_BOVESPA
# : resulted data for 691 periods.
# Executing SPLITS:PCT_CHANGE(1):RAW_BOVESPA : resulted data for 3 periods.
# Executing MACD(5,35,5):CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA : resulted data for 653 periods.
# Executing CLOSE:NORMALIZED:RAW_BOVESPA
# : resulted data for 3278 periods.
# Executing RAW_BOVESPA : resulted data for 3278 periods.
# Executing MONTHLY:NORMALIZED:RAW_BOVESPA : resulted data for 159 periods.
# Executing MACD(12,26,3):CLOSE:NORMALIZED:RAW_BOVESPA
# : resulted data for 3251 periods.
# Executing PCT_CHANGE(1):RAW_BOVESPA : resulted data for 3278 periods.
# Executing MACD(12,26,9):CLOSE:WEEKLY:NORMALIZED:RAW_BOVESPA : resulted data for 658 periods.
# Executing MACD(12,26,9):CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA
# : resulted data for 126 periods.
# Executing MACD(5,35,5):CLOSE:NORMALIZED:RAW_BOVESPA : resulted data for 3240 periods.
# Executing NORMALIZATION_FACTOR:SPLITS:PCT_CHANGE(1):RAW_BOVESPA : resulted data for 3513 periods.
# Executing MACD(12,26,3):CLOSE:MONTHLY:NORMALIZED:RAW_BOVESPA
# : resulted data for 132 periods.
# 1 loops, best of 3: 483 ms per loop

# %% [markdown]
# -----------------------------------------------------

# %%
data_engine.select('NORMALIZED', '{RAW_BOVESPA}').get(0).process(symbol='PETR4', start=dt(2013, 1, 1), end=dt(2013, 2, 1))
# Out:
#              open   high    low  close    volume
# 2013-01-02  19.99  20.21  19.69  19.69  30182600
# 2013-01-03  19.81  20.40  19.70  20.40  30552600
# 2013-01-04  20.33  20.62  20.17  20.48  36141000
# 2013-01-07  20.48  20.67  19.95  20.08  28069600
# 2013-01-08  20.11  20.23  19.46  19.50  29091300
# 2013-01-09  19.64  19.87  19.46  19.68  24361100
# 2013-01-10  19.77  19.88  19.54  19.83  17526200
# 2013-01-11  19.85  20.04  19.70  19.88  18221600
# 2013-01-14  20.01  20.24  19.76  19.85  28302400
# 2013-01-15  20.11  20.15  19.78  19.82  29633900
# 2013-01-16  19.89  19.89  19.60  19.84  16787800
# 2013-01-17  19.86  19.93  19.69  19.71  19719600
# 2013-01-18  19.80  19.89  19.58  19.58  18913900
# 2013-01-21  19.57  19.60  19.27  19.39  18084200
# 2013-01-22  19.42  19.58  19.23  19.58  23535100
# 2013-01-23  19.50  19.63  19.43  19.55  17200800
# 2013-01-24  19.37  19.73  19.37  19.61  19612600
# 2013-01-28  19.73  19.81  19.30  19.37  20122600
# 2013-01-29  19.35  19.37  18.84  19.11  27097800
# 2013-01-30  18.99  18.99  18.17  18.20  66973800
# 2013-01-31  18.26  18.33  17.90  18.08  33241400
# 2013-02-01  18.14  18.65  18.12  18.46  28860200

# %%
data_engine.get('MONTHLY:NORMALIZED:RAW_BOVESPA').process(symbol='PETR4', start=dt(2013, 1, 5), end=dt(2013, 2, 6))
# Out:
# 1
